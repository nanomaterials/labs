# %% [markdown]
# # Черновик лабораторной работы по регулярным фракталам

# %% [markdown]
# # Служебный блок
#
# Этот первый блок - для обсуждения текущей работы. Он будет постоянно варьироваться, и по окончанию выполнения работы будет удален. То есть этот блок выполняет только служебную функцию сопровождения задания.
#
# Сюда можно добавлять любые комментарии и общие вопросы, возникающие по ходу работы, чтобы они были более заметны. После этого блока будет идти все то, что пойдет и в лабораторную работу, и в отчет по учебной практике (фактически сам файл является отчетом о выполнении работы). Когда сделана часть работы, "-" в строке списка заменяем на "+". Комментарии в основном тексте описываются при помощи фигурных скобок.
#
# ## Текущие задания:
# - прочитать то, что касается темы практики
# - разобраться в алгоритме построения фракталов при помощи L-систем
# - освоиться в работе с Jupyter Notebook (Help - User Interface Tour)
# - освоить горячие клавиши Jupyter Notebook (Help - Keyboard Shortcuts) - это существенно ускоряет работу
# - освоить Markdown-разметку текста (используется для оформления текста в Jupyter Notebook)
#
# - начинаем с построения кривой Серпинского, переносим текст, описывающий кривую Серпинского из книги Божокина, Паршина со ссылкой на него (сослаться на источник в списке литературы, например [1, с. 21-22])
# - ознакомиться с примерами [галереи библиотеки matplotlib](https://matplotlib.org/gallery/index.html), изучить код примеров
# - для построения можно оттолкнуться от готовых решений, например, [этот](http://interactivepython.org/courselib/static/thinkcspy/Strings/TurtlesandStringsandLSystems.html), но пока первичная задача - просто научиться строить кривую на экране и понимать что происходит. Для построения графики стандартно используется модуль matplotlib, лучше ориентировать на него.
#
# ## Возникшие вопросы и предложения (пишет Тимерлан, отвечает ЛБМ):
# - ...

# %% [markdown]
# **Цель учебной практики**: подготовить лабораторную работу, в которой будет осуществлено моделирование пяти примеров фрактальных кривых: Серпинского, Пеано, Госпера, Гильберта и Хартера–Хейтуя.
#
# **Задачи учебной практики**:
# * Обучиться программированию на языке Python 3, применяемом для решения различных научных задач;
# * Обучиться использованию Jupyter notebook для описания и программирования математических моделей;
# * Научиться основам LaTeX-разметки математических формул и разметки Markdown;
# * Обучиться основам использования систем контроля версий на примере Git и Github;
# * Изучить и описать основные свойства регулярных фракталов и покрывающих пространство фрактальных кривых;
# * Изучить и запрограммировать представление указанных примеров фрактальных кривых при помощи системы Линденмайера (L-системы);
# * Разработать задание для студентов, проверяющее усвоение полученных в ходе выполнения работы знаний через ввод соответствующих выражений L-систем.

# %% [markdown]
# ## Покрывающие пространство фрактальные кривые

# %% [markdown]
# {во введении этого раздела было бы полезно описать общие свойства покрывающих пространство фрактальных кривых}

# %% [markdown]
# ### Способ описания фраткальных кривых при помощи L-систем
#
# {В тексте этого блока предлагается описать обозначенную в заголовке тему.
#
# Для построения всех пяти кривых предлагается создать одну общую функцию, которой будут передаваться в различных блоках разные аргументы, а именно:
# - правила построения в форме инициирующих строк;
# - количество иттераций;
# насчет этого лучше подумать заранее, но можно сформировать, когда будет сделана программа для отображения кривой Серпинского.
# }

# %%
# блок общей функции построения кривых, записанных при помощи L-систем

# %% [markdown]
# ### Кривая Серпинского

# %% [markdown]
# {Сюда предлагается перенести текст, описывающий данную кривую. Главное не перепутать с салфеткой Серпинского :) Вслед за блоком с описанием будет следовать блок кода.}

# %% [markdown]
# ### Кривая Пеано

# %% [markdown]
# ### Кривая Госпера

# %% [markdown]
# ### Кривая Гильберта

# %% [markdown]
# ### Кривая дракона (кривая Хартера–Хейтуя)

# %% [markdown]
# [Дракон Хартера](https://ru.wikipedia.org/wiki/%D0%9A%D1%80%D0%B8%D0%B2%D0%B0%D1%8F_%D0%B4%D1%80%D0%B0%D0%BA%D0%BE%D0%BD%D0%B0), также известный как дракон Хартера–Хейтуэя, был впервые исследован физиками NASA — Джоном Хейтуэем (John Heighway), Брюсом Бэнксом (Bruce Banks) и Вильямом Хартером (William Harter). Фрактальная кривая была описана в 1967 г. Мартином Гарднером в колонке «Математические игры» журнала Scientific American. Многие свойства фрактала были описаны Чендлером Дэвисом (Chandler Davis) и Дональдом Кнутом.

# %% [markdown]
# # Список литературы

# %% [markdown]
# 1. Божокин С. В., Паршин Д. А. Фракталы и мультифракталы/НИЦ «Регулярная и хаотическая динамика». – 2001.
